# %%
import pickle
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
tsteps = 1024

# %%
# Out:
# 1024

# %% [markdown]
# # Import Data

# %%
def load_broad_config(file_path, grid_size, sample):
    file = open(file_path+"Ising_broad_"+str(grid_size)+"_"+str(sample)+".pickle", 'rb')
    return pickle.load(file)
    
def load_config(file_path, grid_size, sample):
    file = open(file_path+"Ising_"+str(grid_size)+"_"+str(sample)+".pickle", 'rb')
    return pickle.load(file)

# %%
file_path = "C:\\Users\\Ryan\\Documents\\Github\\Masters_Vogt_AMATH563_Final\\"
test = load_config(file_path, 4, 2)

# %% [markdown]
# # Calculate SVDs

# %%
u, s, v = np.linalg.svd(test['State'][0])
print(np.shape(v))
# Out:
# (256, 256)

# %%
size = 4
sing_list = []
u_list = []
v_list = []
for i in range(10):
    sings = np.zeros([size*size, 0])
    us = []
    vs = []
    sample = load_config(file_path, size, i+1)
    for data in tqdm(sample['State']):
        u ,s,v = np.linalg.svd(data)
        sings = np.append(sings, np.expand_dims(s,-1), axis = 1)
        us.append(u)
        vs.append(v)
    sing_list.append(sings)
    u_list.append(us)
    v_list.append(vs)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:10<00:00, 19.46it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:10<00:00, 19.58it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:10<00:00, 18.23it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:11<00:00, 17.69it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:13<00:00, 15.28it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:16<00:00, 12.28it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:14<00:00, 16.91it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:10<00:00, 18.20it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:16<00:00,  4.09it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:15<00:00, 13.17it/s]

# %%
np.shape(X)
# Out:
# (1024, 88)

# %%
fig = plt.figure(figsize =(15,10))
ax1 = plt.subplot(121, projection = '3d')
x = test['Temperature']
y = np.linspace(1, tsteps, tsteps)
X,Y = np.meshgrid(x,y)
z1 = np.array(u_list[0])[:,0, :]
ax1.plot_surface(X, Y, z1.T, edgecolor='none', cmap='viridis')
plt.xlabel('Temperature')
plt.ylabel('Time')
plt.title('Mode 1')
ax1.view_init(30,45)

fig.add_subplot(1, 2, 2)
# ax2 = plt.axes(projection = '3d')
ax2 = plt.subplot(122, projection = '3d')
z2 = np.array(u_list[0])[:,1, :]
ax2.plot_surface(X, Y, z2.T, edgecolor='none', cmap='viridis')
plt.xlabel('Temperature')
plt.ylabel('Time')
plt.title('Mode 2')
ax2.view_init(30,45)

# %%
smsum = np.zeros([size*size, len(sample['Temperature'])])
for sm in sing_list:
    smsum = smsum + sm
smsum = smsum/len(sing_list)

# %%
fig = plt.figure(figsize =(12,12))
ax = plt.axes(projection = '3d')
x = test['Temperature']
y = np.linspace(1, size**2, size**2)
X,Y = np.meshgrid(x,y)
ax.plot_surface(X, Y, smsum, edgecolor='none', cmap='viridis')
plt.xlabel('Temperature')
plt.ylabel('Singular value number')
ax.view_init(30,30)

# %%
# plt.plot(test['Temperature'], smsum[:, 0])
plt.plot([range(size*size)][0], smsum[:, 30])

# %%
plt.plot(test['Temperature'], sings[0, :])

# %%
# Out:
# 496.98506697534356
